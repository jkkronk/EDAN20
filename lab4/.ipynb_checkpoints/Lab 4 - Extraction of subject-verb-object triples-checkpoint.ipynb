# %% [markdown]
# # Lab 4 - Extraction of subject-verb-object triples

# %% [markdown]
# ## Objectives
# The objectives of this assignment are to:
#
# * Extract the subject–verb pairs from a parsed corpus
# * Extend the extraction to subject–verb–object triples
# * Understand how dependency parsing can help create a knowledge base
# * Write a short report of 1 to 2 pages on the assignment

# %% [markdown]
# This assignment is inspired by the Prismatic knowledge base used in the IBM Watson system. See this paper for details.
#
# In this session, you will first use a parsed corpus of Swedish to extract the pairs and triples, and then apply it to other languages.

# %% [markdown]
# ## Choosing a parsed corpus

# %% [markdown]
# #### In this part, you will use the CONLL-X Swedish corpus. Download the tar archives containing the training and test sets for Swedish and uncompress them: [data sets].

# %%
from urllib.request import urlopen

b_train_text = urlopen("http://fileadmin.cs.lth.se/cs/Education/EDAN20/corpus/conll2000/train.txt").read() # Open file and read
train_text = str(b_train_text,'utf-8')

b_test_text = urlopen("http://fileadmin.cs.lth.se/cs/Education/EDAN20/corpus/conll2000/test.txt").read() # Open file and read
test_text = str(b_test_text,'utf-8')

# %%
f_out = open('train_sen', 'w')

for sentence in train_text:   
    f_out.write(sentence)
f_out.close()

# %%
train_text[:511]
# Out:
# "Confidence NN B-NP\nin IN B-PP\nthe DT B-NP\npound NN I-NP\nis VBZ B-VP\nwidely RB I-VP\nexpected VBN I-VP\nto TO I-VP\ntake VB I-VP\nanother DT B-NP\nsharp JJ I-NP\ndive NN I-NP\nif IN B-SBAR\ntrade NN B-NP\nfigures NNS I-NP\nfor IN B-PP\nSeptember NNP B-NP\n, , O\ndue JJ B-ADJP\nfor IN B-PP\nrelease NN B-NP\ntomorrow NN B-NP\n, , O\nfail VB B-VP\nto TO I-VP\nshow VB I-VP\na DT B-NP\nsubstantial JJ I-NP\nimprovement NN I-NP\nfrom IN B-PP\nJuly NNP B-NP\nand CC I-NP\nAugust NNP I-NP\n's POS B-NP\nnear-record JJ I-NP\ndeficits NNS I-NP\n. . O"

# %%
train_text[513:885]
# Out:
# "Chancellor NNP O\nof IN B-PP\nthe DT B-NP\nExchequer NNP I-NP\nNigel NNP B-NP\nLawson NNP I-NP\n's POS B-NP\nrestated VBN I-NP\ncommitment NN I-NP\nto TO B-PP\na DT B-NP\nfirm NN I-NP\nmonetary JJ I-NP\npolicy NN I-NP\nhas VBZ B-VP\nhelped VBN I-VP\nto TO I-VP\nprevent VB I-VP\na DT B-NP\nfreefall NN I-NP\nin IN B-PP\nsterling NN B-NP\nover IN B-PP\nthe DT B-NP\npast JJ I-NP\nweek NN I-NP\n. . O"

# %% [markdown]
# #### Draw a graphical representation of the two first sentences of the training set.

# %% [markdown]
# #### Download What's wrong with my NLP and use it to check your representations.

# %% [markdown]
# First sentence:

# %% [markdown]
# ![Ska%CC%88rmavbild%202019-09-23%20kl.%2011.31.38.png](attachment:Ska%CC%88rmavbild%202019-09-23%20kl.%2011.31.38.png)
#
# ![Ska%CC%88rmavbild%202019-09-23%20kl.%2011.31.55.png](attachment:Ska%CC%88rmavbild%202019-09-23%20kl.%2011.31.55.png)

# %% [markdown]
# Second sentence:

# %% [markdown]
# ![Ska%CC%88rmavbild%202019-09-23%20kl.%2011.35.22.png](attachment:Ska%CC%88rmavbild%202019-09-23%20kl.%2011.35.22.png)

# %% [markdown]
# #### Apply the dependency parser for Swedish of the Langforia pipelines to these sentences. Link to Lanforia pipelines: http://vilde.cs.lth.se:9000/

# %% [markdown]
# First sentence:

# %% [markdown]
# ![Ska%CC%88rmavbild%202019-09-23%20kl.%2011.47.55.png](attachment:Ska%CC%88rmavbild%202019-09-23%20kl.%2011.47.55.png)

# %% [markdown]
# Second sentence:

# %% [markdown]
# ![Ska%CC%88rmavbild%202019-09-23%20kl.%2011.48.09.png](attachment:Ska%CC%88rmavbild%202019-09-23%20kl.%2011.48.09.png)

# %% [markdown]
# ## Extracting the subject–verb pairs and subject–verb–object triples
